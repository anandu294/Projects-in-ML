# 10     2       Rajasthan     6.83    7.93130    7.6840    8.42370    9.97010
# ...

# %%
dataset.drop(columns='state',axis=1,inplace=True)

# %%
dataset
# Out:
#     crop      yd1      year5     year6      year7      year8       year9  \
# 0      0     9.83  198.36282  208.6016  217.28212  230.77504  234.466177
# 1      0     7.47  103.30942  109.8734  110.57622  120.95724  118.138577
# 2      0     9.59   95.05340   98.7282  106.70590  109.81780  116.327600
# 3      0     6.42   83.13170   91.7934   93.35530   96.69290   99.182500
# 4      0     8.72   72.23000   78.2719   80.17080   82.65940   84.908200
# 5      1    12.69   10.90170   13.5215   13.18450   14.03350   14.274300
# 6      1    24.39   68.63690   69.3545   75.80670   78.57020   80.679400
# 7      1    17.83    7.24430    7.6296    7.15080    7.92590    7.245600
# 8      1    19.05    4.04440    4.0716    3.70680    4.11490    3.051900
# 9      1    19.90    3.19990    3.5580    3.44400    3.81100    4.193700
# 10     2     6.83    7.93130    7.6840    8.42370    9.97010    8.887100
# 11     2    10.29   14.17200   14.7099   15.09700   18.95540   19.731400
# ...

# %%
dataset.isnull().any()
# Out:
# crop      False
# yd1       False
# year5     False
# year6     False
# year7     False
# year8     False
# year9     False
# year10    False
# year11    False
# year12    False
# year13    False
# year14    False
# dtype: bool

# %%
x=dataset.iloc[:,:-1].values
x
# Out:
# array([[0.00000000e+00, 9.83000000e+00, 1.98362820e+02, 2.08601600e+02,
#         2.17282120e+02, 2.30775040e+02, 2.34466177e+02, 2.18107372e+02,
#         2.44491809e+02, 2.59286253e+02, 2.57130000e+02],
#        [0.00000000e+00, 7.47000000e+00, 1.03309420e+02, 1.09873400e+02,
#         1.10576220e+02, 1.20957240e+02, 1.18138577e+02, 1.03954032e+02,
#         1.20853191e+02, 1.31274812e+02, 1.28070000e+02],
#        [0.00000000e+00, 9.59000000e+00, 9.50534000e+01, 9.87282000e+01,
#         1.06705900e+02, 1.09817800e+02, 1.16327600e+02, 1.14153340e+02,
#         1.23638618e+02, 1.28011441e+02, 1.29060000e+02],
#        [0.00000000e+00, 6.42000000e+00, 8.31317000e+01, 9.17934000e+01,
#         9.33553000e+01, 9.66929000e+01, 9.91825000e+01, 8.90929010e+01,
#         9.59798192e+01, 1.05301100e+02, 1.05240000e+02],
#        [0.00000000e+00, 8.72000000e+00, 7.22300000e+01, 7.82719000e+01,
#         8.01708000e+01, 8.26594000e+01, 8.49082000e+01, 7.59165100e+01,
# ...

# %%
y=dataset.iloc[:,-1:].values
y
# Out:
# array([[2.643806e+02],
#        [1.293686e+02],
#        [1.350120e+02],
#        [1.062872e+02],
#        [9.200930e+01],
#        [1.427790e+01],
#        [9.584920e+01],
#        [5.246700e+00],
#        [2.229200e+00],
#        [3.017500e+00],
#        [9.185500e+00],
#        [2.419090e+01],
#        [1.750560e+01],
#        [6.685300e+00],
#        [1.877500e+00],
#        [4.454000e-01],
#        [1.730300e+00],
#        [4.267630e+01],
#        [3.124320e+01],
#        [1.143310e+01],
#        [2.448127e+02],
#        [1.232525e+02],
#        [1.215602e+02],
#        [3.382200e+00],
#        [6.692000e-01],
#        [9.925300e+00],
#        [2.689900e+00],
#        [1.956790e+01],
#        [6.116100e+00],
#        [1.345180e+01],
#        [3.241430e+01],
#        [2.213660e+01],
#        [1.027770e+01],
#        [9.471500e+00],
#        [7.655700e+00],
#        [1.815800e+00],
#        [1.643800e+00],
#        [6.361000e-01],
#        [8.750000e-02],
#        [7.828900e+00],
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[2.00000000e+00, 1.02900000e+01, 1.41720000e+01, 1.47099000e+01,
#         1.50970000e+01, 1.89554000e+01, 1.97314000e+01, 1.67194670e+01,
#         2.17257520e+01, 2.17593720e+01, 2.22600000e+01],
#        [6.00000000e+00, 3.24200000e+01, 1.41492000e+01, 1.67670000e+01,
#         1.40121000e+01, 2.07134000e+01, 1.78079690e+01, 1.57284290e+01,
#         2.19220220e+01, 2.06910640e+01, 2.07910000e+01],
#        [6.00000000e+00, 6.74100000e+01, 6.77440000e+00, 7.99330000e+00,
#         4.86350000e+00, 9.18250000e+00, 7.16810000e+00, 5.42849300e+00,
#         8.26478200e+00, 6.96371200e+00, 4.69500000e+00],
#        [5.00000000e+00, 1.32000000e+00, 1.31295000e+01, 1.33844000e+01,
#         1.41975200e+01, 1.47615400e+01, 1.45663774e+01, 1.46617890e+01,
#         1.82409455e+01, 1.70891239e+01, 1.83400000e+01],
#        [9.00000000e+00, 3.71900000e+01, 8.73000000e-01, 8.70100000e-01,
#         9.55900000e-01, 9.90400000e-01, 7.30900000e-01, 5.87028000e-01,
# ...

# %%
x_test
# Out:
# array([[5.00000000e+00, 6.70000000e+00, 8.41220000e+00, 8.51960000e+00,
#         9.40210000e+00, 8.35830000e+00, 9.88020000e+00, 1.04575870e+01,
#         1.11208445e+01, 1.10310829e+01, 1.24300000e+01],
#        [0.00000000e+00, 8.72000000e+00, 7.22300000e+01, 7.82719000e+01,
#         8.01708000e+01, 8.26594000e+01, 8.49082000e+01, 7.59165100e+01,
#         8.06512411e+01, 9.27807000e+01, 9.23700000e+01],
#        [5.00000000e+00, 4.05000000e+00, 2.31700000e+00, 2.31090000e+00,
#         2.28780000e+00, 2.00170000e+00, 2.23370000e+00, 2.30803757e+00,
#         2.27046883e+00, 2.40135890e+00, 2.73000000e+00],
#        [6.00000000e+00, 3.66100000e+01, 2.43535000e+01, 2.79779000e+01,
#         2.42894000e+01, 2.97553000e+01, 2.77189520e+01, 2.48816240e+01,
#         3.24789560e+01, 2.97986417e+01, 3.09430000e+01],
#        [6.00000000e+00, 3.90400000e+01, 1.02043000e+01, 1.12109000e+01,
#         1.02773000e+01, 9.04190000e+00, 9.91098300e+00, 9.15319500e+00,
# ...

# %%
y_train
# Out:
# array([[2.419090e+01],
#        [2.213660e+01],
#        [9.471500e+00],
#        [1.956790e+01],
#        [5.795000e-01],
#        [1.350120e+02],
#        [3.650000e+01],
#        [3.124320e+01],
#        [4.454000e-01],
#        [6.116100e+00],
#        [1.215602e+02],
#        [1.730300e+00],
#        [1.159000e-01],
#        [2.448127e+02],
#        [5.417000e-01],
#        [2.229200e+00],
#        [6.685300e+00],
#        [9.925300e+00],
#        [1.427790e+01],
#        [4.267630e+01],
#        [1.815800e+00],
#        [1.877500e+00],
#        [8.750000e-02],
#        [1.293686e+02],
#        [1.750560e+01],
#        [1.655000e-01],
#        [6.692000e-01],
#        [9.584920e+01],
#        [3.382200e+00],
#        [1.643800e+00],
#        [1.232525e+02],
#        [1.143310e+01],
#        [3.017500e+00],
#        [7.828900e+00],
#        [1.194800e+01],
#        [1.062872e+02],
#        [2.643806e+02],
#        [1.082100e+01],
#        [3.762000e-01]])

# %%
y_test
# Out:
# array([[13.4518],
#        [92.0093],
#        [ 2.6899],
#        [32.4143],
#        [10.2777],
#        [ 0.6361],
#        [ 7.6557],
#        [ 0.1409],
#        [ 5.2467],
#        [ 9.1855]])

# %%
plt.scatter(x[:,5],y)

# %%
plt.scatter(x[:,6],y)

# %%
plt.scatter(x[:,8],y)

# %%
plt.scatter(x[:,10],y)

# %%
plt.scatter(x[:,10],y)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_predict=lr.predict(x_test)
y_predict
# Out:
# array([[12.61826027],
#        [91.57617623],
#        [ 2.57687733],
#        [33.59249199],
#        [10.80930473],
#        [ 0.79743588],
#        [ 6.25072334],
#        [ 0.21650959],
#        [ 5.68941015],
#        [ 9.33211007]])

# %%
lr.predict(x_test)
# Out:
# array([[12.61826027],
#        [91.57617623],
#        [ 2.57687733],
#        [33.59249199],
#        [10.80930473],
#        [ 0.79743588],
#        [ 6.25072334],
#        [ 0.21650959],
#        [ 5.68941015],
#        [ 9.33211007]])

# %%
a = lr.predict([[5.00000000e+00, 6.70000000e+00, 8.41220000e+00, 8.51960000e+00,
        9.40210000e+00, 8.35830000e+00, 9.88020000e+00, 1.04575870e+01,
        1.11208445e+01, 1.10310829e+01, 1.24300000e+01]])

# %%
a
# Out:
# array([[12.61826027]])

# %%
b=lr.predict([[0.00000000e+00, 8.72000000e+00, 7.22300000e+01, 7.82719000e+01,
        8.01708000e+01, 8.26594000e+01, 8.49082000e+01, 7.59165100e+01,
        8.06512411e+01, 9.27807000e+01, 9.23700000e+01]])

# %%
b
# Out:
# array([[91.57617621]])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_predict)
# Out:
# 0.9993122785759506
